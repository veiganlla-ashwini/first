# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # New Section

# %%
import pandas as pd
d=pd.read_csv('/content/district.csv')
print(d)
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
from matplotlib import pyplot as pt

# %%
x=d['Mar-May']
y=d['Jun-Sep']
pt.plot(x,y)

# %%
x=d['JAN']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['FEB']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['MAR']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['APR']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['MAY']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['JUN']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['JUL']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['AUG']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['SEP']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['OCT']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['NOV']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=d['DEC']
y=d['ANNUAL']
pt.plot(x,y)

# %%
x=x=d['Jan-Feb']
y=d['Mar-May']
pt.plot(x,y)

# %%
x=d['Mar-May']
y=d['Jun-Sep']
pt.plot(x,y)

# %%
x=d['Jun-Sep']
y=d['Oct-Dec']
pt.plot(x,y)

# %%
import pandas as pd

# %%
import pandas as pd
d=pd.read_csv('/content/district.csv')
print(d.isnull())
# Out:
#      STATE_UT_NAME  DISTRICT    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 0            False     False  False  False  False  False  False  False  False
# 1            False     False  False  False  False  False  False  False  False
# 2            False     False  False  False  False  False  False  False  False
# 3            False     False  False  False  False  False  False  False  False
# 4            False     False  False  False  False  False  False  False  False
# ..             ...       ...    ...    ...    ...    ...    ...    ...    ...
# 636          False     False  False  False  False  False  False  False  False
# 637          False     False  False  False  False  False  False  False  False
# 638          False     False  False  False  False  False  False  False  False
# 639          False     False  False  False  False  False  False  False  False
# 640          False     False  False  False  False  False  False  False  False
#
# ...

# %%
import pandas as pd
d=pd.read_csv('/content/district.csv')
print(d.describe())
print(d)
# Out:
#               JAN         FEB         MAR         APR         MAY  \
# count  641.000000  641.000000  641.000000  641.000000  641.000000
# mean    18.355070   20.984399   30.034789   45.543214   81.535101
# std     21.082806   27.729596   45.451082   71.556279  111.960390
# min      0.000000    0.000000    0.000000    0.000000    0.900000
# 25%      6.900000    7.000000    7.000000    5.000000   12.100000
# 50%     13.300000   12.300000   12.700000   15.100000   33.900000
# 75%     19.200000   24.100000   33.200000   48.300000   91.900000
# max    144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   641.000000   641.000000   641.000000  641.000000  641.000000
# mean    196.007332   326.033697   291.152262  194.609048   90.446334
# std     196.556284   221.364643   152.647325   99.830540   74.990685
# min       3.800000    11.600000    14.100000    8.600000    3.100000
# ...

# %%
import seaborn as sns

# %%
import seaborn as sns
sns.boxplot(data=d,x='JAN')
# Out:
# <Axes: xlabel='JAN'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='FEB')
# Out:
# <Axes: xlabel='FEB'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='MAR')
# Out:
# <Axes: xlabel='MAR'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='APR')
# Out:
# <Axes: xlabel='APR'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='MAY')
# Out:
# <Axes: xlabel='MAY'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='JUN')
# Out:
# <Axes: xlabel='JUN'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='JUL')
# Out:
# <Axes: xlabel='JUL'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='AUG')
# Out:
# <Axes: xlabel='AUG'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='SEP')
# Out:
# <Axes: xlabel='SEP'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='OCT')
# Out:
# <Axes: xlabel='OCT'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='NOV')
# Out:
# <Axes: xlabel='NOV'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='DEC')
# Out:
# <Axes: xlabel='DEC'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='ANNUAL')
# Out:
# <Axes: xlabel='ANNUAL'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Jan-Feb')
# Out:
# <Axes: xlabel='Jan-Feb'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Mar-May')
# Out:
# <Axes: xlabel='Mar-May'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Jun-Sep')
# Out:
# <Axes: xlabel='Jun-Sep'>

# %%
import seaborn as sns
sns.boxplot(data=d,x='Oct-Dec')
# Out:
# <Axes: xlabel='Oct-Dec'>

# %%
corr_matrix=d.corr()
print(corr_matrix)
# Out:
#               JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# JAN      1.000000  0.868628  0.688776  0.343254  0.154175 -0.030926 -0.007617
# FEB      0.868628  1.000000  0.899637  0.633236  0.394301  0.194324  0.141263
# MAR      0.688776  0.899637  1.000000  0.838087  0.609177  0.362265  0.204693
# APR      0.343254  0.633236  0.838087  1.000000  0.885394  0.630982  0.388887
# MAY      0.154175  0.394301  0.609177  0.885394  1.000000  0.785813  0.520490
# JUN     -0.030926  0.194324  0.362265  0.630982  0.785813  1.000000  0.880365
# JUL     -0.007617  0.141263  0.204693  0.388887  0.520490  0.880365  1.000000
# AUG      0.027202  0.153355  0.171421  0.299930  0.427825  0.758769  0.930407
# SEP      0.014375  0.211977  0.337046  0.550991  0.690867  0.805113  0.776188
# OCT      0.002580  0.184534  0.336384  0.586121  0.704970  0.633108  0.371574
# NOV      0.114688  0.099818  0.109066  0.204731  0.253589  0.127333 -0.058499
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
cov_matrix=d.corr()
print(corr_matrix)
# Out:
#               JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# JAN      1.000000  0.868628  0.688776  0.343254  0.154175 -0.030926 -0.007617
# FEB      0.868628  1.000000  0.899637  0.633236  0.394301  0.194324  0.141263
# MAR      0.688776  0.899637  1.000000  0.838087  0.609177  0.362265  0.204693
# APR      0.343254  0.633236  0.838087  1.000000  0.885394  0.630982  0.388887
# MAY      0.154175  0.394301  0.609177  0.885394  1.000000  0.785813  0.520490
# JUN     -0.030926  0.194324  0.362265  0.630982  0.785813  1.000000  0.880365
# JUL     -0.007617  0.141263  0.204693  0.388887  0.520490  0.880365  1.000000
# AUG      0.027202  0.153355  0.171421  0.299930  0.427825  0.758769  0.930407
# SEP      0.014375  0.211977  0.337046  0.550991  0.690867  0.805113  0.776188
# OCT      0.002580  0.184534  0.336384  0.586121  0.704970  0.633108  0.371574
# NOV      0.114688  0.099818  0.109066  0.204731  0.253589  0.127333 -0.058499
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(cov_matrix,annot=True)
# Out:
# <Axes: >
